# %%
# install castle-ai with cuda and pytorch
# !pip install castle-ai[cuda,pytorch] \
    --extra-index-url https://download.pytorch.org/whl/cu121 \
    --extra-index-url https://pypi.nvidia.com

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# create a project folder in drive
# !mkdir -p /content/drive/MyDrive/castle-projects

# run the web interface
# !castle-ai --project-folder /content/drive/MyDrive/castle-projects
